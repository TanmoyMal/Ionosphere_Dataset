# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

data = pd.read_csv("/content/Ionosphere (1).csv")

# pd.set_option('display.max_rows', None)

data
# Out:
#      V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 0     1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1     1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2     1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3     1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4     1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
# ..   ..  ..      ...      ...      ...      ...      ...      ...      ...
# 346   1   0  0.83508  0.08298  0.73739 -0.14706  0.84349 -0.05567  0.90441
# 347   1   0  0.95113  0.00419  0.95183 -0.02723  0.93438 -0.01920  0.94590
# 348   1   0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431  0.95584
# 349   1   0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646  0.85746
# 350   1   0  0.84710  0.13533  0.73638 -0.06151  0.87873  0.08260  0.88928
#
# ...

# %%
data.shape
# Out:
# (351, 35)

# %%
data.head(10)
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
# 5   1   0  0.02337 -0.00592 -0.09924 -0.11949 -0.00763 -0.11824  0.14706
# 6   1   0  0.97588 -0.10602  0.94601 -0.20800  0.92806 -0.28350  0.85996
# 7   0   0  0.00000  0.00000  0.00000  0.00000  1.00000 -1.00000  0.00000
# 8   1   0  0.96355 -0.07198  1.00000 -0.14333  1.00000 -0.21313  1.00000
# 9   1   0 -0.01864 -0.08459  0.00000  0.00000  0.00000  0.00000  0.11470
#
#        V10  ...      V26      V27      V28      V29      V30      V31  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# ...

# %%
data.tail(10)
# Out:
#      V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 341   1   0  0.98002  0.00075  1.00000  0.00000  0.98982 -0.00075  0.94721
# 342   1   0  0.82254 -0.07572  0.80462  0.00231  0.87514 -0.01214  0.86821
# 343   1   0  0.35346 -0.13768  0.69387 -0.02423  0.68195 -0.03574  0.55717
# 344   1   0  0.76046  0.01092  0.86335  0.00258  0.85821  0.00384  0.79988
# 345   1   0  0.66667 -0.01366  0.97404  0.06831  0.49590  0.50137  0.75683
# 346   1   0  0.83508  0.08298  0.73739 -0.14706  0.84349 -0.05567  0.90441
# 347   1   0  0.95113  0.00419  0.95183 -0.02723  0.93438 -0.01920  0.94590
# 348   1   0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431  0.95584
# 349   1   0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646  0.85746
# 350   1   0  0.84710  0.13533  0.73638 -0.06151  0.87873  0.08260  0.88928
#
#          V10  ...      V26      V27      V28      V29      V30      V31  \
# ...

# %%
df = pd.read_csv("/content/Ionosphere (1).csv", usecols=['V6', 'V29'])
df

#read the particulat row from the data set
# Out:
#           V6      V29
# 0    0.02306  0.21266
# 1   -0.36156 -0.19040
# 2    0.00485  0.43100
# 3    1.00000  1.00000
# 4    0.06531  0.02431
# ..       ...      ...
# 346 -0.14706  1.00000
# 347 -0.02723  0.93159
# 348 -0.03227  0.92120
# 349 -0.01989  0.82983
# 350 -0.06151  0.78207
#
# [351 rows x 2 columns]

# %%
data.describe()
# Out:
#                V1     V2          V3          V4          V5          V6  \
# count  351.000000  351.0  351.000000  351.000000  351.000000  351.000000
# mean     0.891738    0.0    0.641342    0.044372    0.601068    0.115889
# std      0.311155    0.0    0.497708    0.441435    0.519862    0.460810
# min      0.000000    0.0   -1.000000   -1.000000   -1.000000   -1.000000
# 25%      1.000000    0.0    0.472135   -0.064735    0.412660   -0.024795
# 50%      1.000000    0.0    0.871110    0.016310    0.809200    0.022800
# 75%      1.000000    0.0    1.000000    0.194185    1.000000    0.334655
# max      1.000000    0.0    1.000000    1.000000    1.000000    1.000000
#
#                V7          V8          V9         V10  ...         V26  \
# count  351.000000  351.000000  351.000000  351.000000  ...  351.000000
# mean     0.550095    0.119360    0.511848    0.181345  ...   -0.071187
# std      0.492654    0.520750    0.507066    0.483851  ...    0.508495
# ...

# %%
data.isnull()
# Out:
#         V1     V2     V3     V4     V5     V6     V7     V8     V9    V10  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 346  False  False  False  False  False  False  False  False  False  False
# 347  False  False  False  False  False  False  False  False  False  False
# 348  False  False  False  False  False  False  False  False  False  False
# 349  False  False  False  False  False  False  False  False  False  False
# 350  False  False  False  False  False  False  False  False  False  False
#
#      ...    V26    V27    V28    V29    V30    V31    V32    V33    V34  Class
# ...

# %%
dt=data.iloc[1:3]
print(dt)
# Out:
#    V1  V2   V3       V4       V5       V6       V7       V8       V9      V10  \
# 1   1   0  1.0 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000 -0.04549
# 2   1   0  1.0 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965  0.01198
#
#    ...      V26      V27      V28     V29      V30      V31      V32      V33  \
# 1  ... -0.26569 -0.20468 -0.18401 -0.1904 -0.11593 -0.16626 -0.06288 -0.13738
# 2  ... -0.40220  0.58984 -0.22145  0.4310 -0.17365  0.60436 -0.24180  0.56045
#
#        V34  Class
# 1 -0.02447      0
# 2 -0.38238      1
#
# [2 rows x 35 columns]

# %%
data.isnull().sum()
# Out:
# V1       0
# V2       0
# V3       0
# V4       0
# V5       0
# V6       0
# V7       0
# V8       0
# V9       0
# V10      0
# V11      0
# V12      0
# V13      0
# V14      0
# V15      0
# V16      0
# V17      0
# V18      0
# V19      0
# V20      0
# V21      0
# V22      0
# V23      0
# V24      0
# V25      0
# V26      0
# V27      0
# V28      0
# V29      0
# V30      0
# V31      0
# V32      0
# V33      0
# V34      0
# Class    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31',
#        'V32', 'V33', 'V34', 'Class'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data=data[['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
       'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
       'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31',
       'V32', 'V33', 'V34', 'Class']])
plt.title('Boxplot of Features')
plt.show()

# %%
plt.figure(figsize=(14, 6))
avg_measurements = data[['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
       'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
       'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31',
       'V32', 'V33', 'V34', 'Class']].mean()
sns.barplot(x=avg_measurements.index, y=avg_measurements.values)
plt.title('Barplot of Average Measurements')
plt.ylabel('Average Measurement')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['V5'], y=data['V20'], hue=data['V1'])
plt.title('Scatterplot of V5 vs V20')
plt.xlabel('V5')
plt.ylabel('V20')
plt.legend(title='Species')
plt.show()

# %%
corr=data[['V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11','V12']].corr()
sns.heatmap(corr)
# Out:
# <Axes: >
